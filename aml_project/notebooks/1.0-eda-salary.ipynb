# %%
from aml_prediction.dataset import SalaryDataset
from aml_prediction.modeling.train import run_training
from aml_prediction import plots

ds = SalaryDataset().load().clean()
ds.data.head()

model, preprocessor, X_test_t, y_test = run_training()

y_pred = model.predict(X_test_t)
plots.plot_confusion(y_test, y_pred)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Duplicados eliminados: 24
# Duplicados eliminados: 24
